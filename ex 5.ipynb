# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Binance_EOSUSDT_d.csv")
high=pd.DataFrame(df['high'],range(0,100))
# df
# Out:
#                unix                 date    symbol     open     high      low  \
# 0     1635724800000  2021-11-01 00:00:00  EOS/USDT   4.6370   4.7200   4.6010
# 1     1635638400000  2021-10-31 00:00:00  EOS/USDT   4.4800   4.7730   4.4430
# 2     1635552000000  2021-10-30 00:00:00  EOS/USDT   4.5020   4.5240   4.3480
# 3     1635465600000  2021-10-29 00:00:00  EOS/USDT   4.4010   4.5420   4.3740
# 4     1635379200000  2021-10-28 00:00:00  EOS/USDT   4.1510   4.4950   4.1330
# ...             ...                  ...       ...      ...      ...      ...
# 1249  1527811200000  2018-06-01 00:00:00  EOS/USDT  12.2351  12.3889  11.8354
# 1250  1527724800000  2018-05-31 00:00:00  EOS/USDT  11.8712  12.7400  11.8116
# 1251  1527638400000  2018-05-30 00:00:00  EOS/USDT  12.1113  12.8200  11.6206
# 1252  1527552000000  2018-05-29 00:00:00  EOS/USDT  11.4853  12.4650  10.7000
# 1253  1527465600000  2018-05-28 00:00:00  EOS/USDT  12.4900  12.6500  11.2800
#
# ...

# %%
Volume_Eos= df["Volume EOS"].values
Volume_USDT= df["Volume USDT"].values
Correlation_Coefficient = np.corrcoef(Volume_Eos, Volume_USDT)
print(f"Correlation Coefficient is: {Correlation_Coefficient}")
# Out:
# Correlation Coefficient is: [[1.         0.89127292]
#  [0.89127292 1.        ]]
